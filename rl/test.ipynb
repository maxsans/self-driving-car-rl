# %%
import gymnasium as gym

from stable_baselines3 import DQN

env = gym.make("CartPole-v1", render_mode="human")

model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)
model.save("dqn_cartpole")

del model # remove to demonstrate saving and loading

model = DQN.load("dqn_cartpole")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 43       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 109      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.583    |
# |    n_updates        | 2        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 44       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 190      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.552    |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 39       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 274      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 38       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 389      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.449    |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 39       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 460      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.418    |
# |    n_updates        | 89       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 40       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 517      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.377    |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 40       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 576      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.323    |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 40       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 623      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.317    |
# |    n_updates        | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 40       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 668      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.259    |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.311    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 41       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 725      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.25     |
# |    n_updates        | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 41       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 768      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.2      |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 41       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 817      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.182    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 41       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 861      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.147    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 41       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 898      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 199      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 41       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 940      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.0709   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 41       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 978      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 219      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 41       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.146    |
# |    n_updates        | 228      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 41       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1053     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0949   |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 41       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1090     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0855   |
# |    n_updates        | 247      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 41       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1126     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0895   |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 42       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0773   |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 42       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1207     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0581   |
# |    n_updates        | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 42       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1248     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0619   |
# |    n_updates        | 286      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 env = gym.make("CartPole-v1", render_mode="human")
#       7 model = DQN("MlpPolicy", env, verbose=1)
# ----> 8 model.learn(total_timesteps=10000, log_interval=4)
#       9 model.save("dqn_cartpole")
#      11 del model # remove to demonstrate saving and loading
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/envs/classic_control/cartpole.py:223, in CartPoleEnv.step(self, action)
#     220     reward = -1.0 if self._sutton_barto_reward else 0.0
#     222 if self.render_mode == "human":
# --> 223     self.render()
#     225 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     226 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/Documents/ESEO/S9/IA/projet-self-driving-car/venv/lib/python3.9/site-packages/gymnasium/envs/classic_control/cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
